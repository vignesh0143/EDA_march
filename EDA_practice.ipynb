# %%
import pandas as pd,numpy as np,matplotlib.pyplot as plt,seaborn as sns

# %%
visa_df=pd.read_csv('Visadataset.csv')
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_df.head()
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# ...

# %%
visa_df.tail()
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 25475                South         77092.57         Year                  Y
# ...

# %%
visa_df.take([4],axis=1)
# Out:
#       requires_job_training
# 0                         N
# 1                         N
# 2                         Y
# 3                         N
# 4                         N
# ...                     ...
# 25475                     Y
# 25476                     N
# 25477                     N
# 25478                     Y
# 25479                     N
#
# [25480 rows x 1 columns]

# %%
ede=visa_df['education_of_employee']=='High School'
visa_df[ede]
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia           High School                  Y
# 2         EZYV03      Asia           High School                  N
# 3         EZYV04      Asia           High School                  N
# 4         EZYV05    Africa           High School                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia           High School                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia           High School                  Y
# 25478  EZYV25479      Asia           High School                  Y
# 25479  EZYV25480      Asia           High School                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_df=pd.read_csv('Visadataset.csv')
unique_col=visa_df['education_of_employee'].unique()
val_con=[]
for i in unique_col:
    con=visa_df['education_of_employee']==i
    val=len(visa_df[con])
    val_con.append(val)
    print(i,val)
# Out:
# High School 3420
# Master's 9634
# Bachelor's 10234
# Doctorate 2192

# %%
A=pd.DataFrame(zip(unique_col,val_con),columns=['education_of_employees','count'])
A
# Out:
#   education_of_employees  count
# 0            High School   3420
# 1               Master's   9634
# 2             Bachelor's  10234
# 3              Doctorate   2192

# %%
A.to_csv('education_of_employees_df.csv',index=False)

# %%
plt.figure(figsize=(5,5))
plt.bar('education_of_employees','count',data=A)
plt.show()

# %%
plt.pie(val_con,explode=[0.1,0.1,0.1,0.1],labels=unique_col,autopct='%0.2f%%',startangle=180,radius=2)
plt.show()

# %%
visa_df.describe()
# Out:
#        no_of_employees   yr_of_estab  prevailing_wage
# count         8.000000      8.000000         8.000000
# mean      82837.871507   4661.972107     85502.920765
# std      210038.327651   8438.815533    100070.590243
# min         -26.000000     42.366929         2.136700
# 25%        1837.250000   1932.000000     31881.610000
# 50%        4585.521605   1988.204965     61562.076163
# 75%       23528.446636   2007.750000     82775.739069
# max      602069.000000  25480.000000    319210.270000

# %%
visa_df=pd.read_csv('Visadataset.csv')
