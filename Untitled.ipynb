# %%
import pandas as pd,numpy as np,matplotlib.pyplot as plt,seaborn as sns

# %%
bank=pd.read_csv('bank-additional.csv',sep=';')

# %%
bank
# Out:
#       age          job  marital          education default  housing     loan  \
# 0      30  blue-collar  married           basic.9y      no      yes       no
# 1      39     services   single        high.school      no       no       no
# 2      25     services  married        high.school      no      yes       no
# 3      38     services  married           basic.9y      no  unknown  unknown
# 4      47       admin.  married  university.degree      no      yes       no
# ...   ...          ...      ...                ...     ...      ...      ...
# 4114   30       admin.  married           basic.6y      no      yes      yes
# 4115   39       admin.  married        high.school      no      yes       no
# 4116   27      student   single        high.school      no       no       no
# 4117   58       admin.  married        high.school      no       no       no
# 4118   34   management   single        high.school      no      yes       no
#
# ...

# %%
bank.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4119 entries, 0 to 4118
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             4119 non-null   int64
#  1   job             4119 non-null   object
#  2   marital         4119 non-null   object
#  3   education       4119 non-null   object
#  4   default         4119 non-null   object
#  5   housing         4119 non-null   object
#  6   loan            4119 non-null   object
#  7   contact         4119 non-null   object
#  8   month           4119 non-null   object
#  9   day_of_week     4119 non-null   object
#  10  duration        4119 non-null   int64
#  11  campaign        4119 non-null   int64
#  12  pdays           4119 non-null   int64
#  13  previous        4119 non-null   int64
#  14  poutcome        4119 non-null   object
#  15  emp.var.rate    4119 non-null   float64
#  16  cons.price.idx  4119 non-null   float64
# ...

# %%
bank.head()
# Out:
#    age          job  marital          education default  housing     loan  \
# 0   30  blue-collar  married           basic.9y      no      yes       no
# 1   39     services   single        high.school      no       no       no
# 2   25     services  married        high.school      no      yes       no
# 3   38     services  married           basic.9y      no  unknown  unknown
# 4   47       admin.  married  university.degree      no      yes       no
#
#      contact month day_of_week  ...  campaign  pdays  previous     poutcome  \
# 0   cellular   may         fri  ...         2    999         0  nonexistent
# 1  telephone   may         fri  ...         4    999         0  nonexistent
# 2  telephone   jun         wed  ...         1    999         0  nonexistent
# 3  telephone   jun         fri  ...         3    999         0  nonexistent
# 4   cellular   nov         mon  ...         1    999         0  nonexistent
#
# ...

# %%
missing_values = Bank.isnull().sum()
missing_values
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
categorical_columns=bank.select_dtypes(include=object).columns
categorical_columns
# Out:
# Index(['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact',
#        'month', 'day_of_week', 'poutcome', 'y'],
#       dtype='object')

# %%
unque_job=bank['job'].unique()
count_list=[]
for i in unque_job:
    con=bank['job']==i
    val=len(bank[con])
    count_list.append(val)
job_df=pd.DataFrame(zip(unque_job,count_list),columns=['jobs','count'])
job_df
# Out:
#              jobs  count
# 0     blue-collar    884
# 1        services    393
# 2          admin.   1012
# 3    entrepreneur    148
# 4   self-employed    159
# 5      technician    691
# 6      management    324
# 7         student     82
# 8         retired    166
# 9       housemaid    110
# 10     unemployed    111
# 11        unknown     39

# %%
unque_marital=bank['marital'].unique()
count_list1=[]
for i in unque_marital:
    con1=bank['marital']==i
    val1=len(bank[con1])
    count_list1.append(val1)
marital_df=pd.DataFrame(zip(unque_marital,count_list1),columns=['marital','count'])
marital_df
# Out:
#     marital  count
# 0   married   2509
# 1    single   1153
# 2  divorced    446
# 3   unknown     11

# %%
unque_education=bank['education'].unique()
count_list2=[]
for i in unque_education:
    con2=bank['education']==i
    val2=len(bank[con2])
    count_list2.append(val2)
education_df=pd.DataFrame(zip(unque_education,count_list2),columns=['education','count'])
education_df
# Out:
#              education  count
# 0             basic.9y    574
# 1          high.school    921
# 2    university.degree   1264
# 3  professional.course    535
# 4             basic.6y    228
# 5             basic.4y    429
# 6              unknown    167
# 7           illiterate      1

# %%
unque_default=bank['default'].unique()
count_list3=[]
for i in unque_default:
    con3=bank['default']==i
    val3=len(bank[con3])
    count_list3.append(val3)
default_df=pd.DataFrame(zip(unque_default,count_list3),columns=['default','count'])
default_df
# Out:
#    default  count
# 0       no   3315
# 1  unknown    803
# 2      yes      1

# %%
unque_housing=bank['housing'].unique()
count_list4=[]
for i in unque_housing:
    con4=bank['housing']==i
    val4=len(bank[con4])
    count_list4.append(val4)
housing_df=pd.DataFrame(zip(unque_housing,count_list4),columns=['housing','count'])
housing_df
# Out:
#    housing  count
# 0      yes   2175
# 1       no   1839
# 2  unknown    105

# %%
unque_loan=bank['loan'].unique()
count_list5=[]
for i in unque_loan:
    con5=bank['loan']==i
    val5=len(bank[con5])
    count_list5.append(val5)
loan_df=pd.DataFrame(zip(unque_loan,count_list5),columns=['loan','count'])
loan_df
# Out:
#       loan  count
# 0       no   3349
# 1  unknown    105
# 2      yes    665

# %%
unque_contact=bank['contact'].unique()
count_list6=[]
for i in unque_contact:
    con6=bank['contact']==i
    val6=len(bank[con6])
    count_list6.append(val6)
contact_df=pd.DataFrame(zip(unque_contact,count_list6),columns=['contact','count'])
contact_df
# Out:
#      contact  count
# 0   cellular   2652
# 1  telephone   1467

# %%
unque_month=bank['month'].unique()
count_list7=[]
for i in unque_month:
    con7=bank['month']==i
    val7=len(bank[con7])
    count_list7.append(val7)
month_df=pd.DataFrame(zip(unque_month,count_list7),columns=['month','count'])
month_df
# Out:
#   month  count
# 0   may   1378
# 1   jun    530
# 2   nov    446
# 3   sep     64
# 4   jul    711
# 5   aug    636
# 6   mar     48
# 7   oct     69
# 8   apr    215
# 9   dec     22

# %%
unque_day_of_week=bank['day_of_week'].unique()
count_list8=[]
for i in unque_day_of_week:
    con8=bank['day_of_week']==i
    val8=len(bank[con8])
    count_list8.append(val8)
day_of_week_df=pd.DataFrame(zip(unque_day_of_week,count_list8),columns=['day_of_week','count'])
day_of_week_df
# Out:
#   day_of_week  count
# 0         fri    768
# 1         wed    795
# 2         mon    855
# 3         thu    860
# 4         tue    841

# %%
unque_poutcome=bank['poutcome'].unique()
count_list9=[]
for i in unque_poutcome:
    con9=bank['poutcome']==i
    val9=len(bank[con9])
    count_list9.append(val9)
poutcome_df=pd.DataFrame(zip(unque_poutcome,count_list9),columns=['poutcome','count'])
poutcome_df
# Out:
#       poutcome  count
# 0  nonexistent   3523
# 1      failure    454
# 2      success    142

# %%
unque_y=bank['y'].unique()
count_list10=[]
for i in unque_y:
    con10=bank['y']==i
    val10=len(bank[con10])
    count_list10.append(val10)
y_df=pd.DataFrame(zip(unque_y,count_list10),columns=['y','count'])
y_df
# Out:
#      y  count
# 0   no   3668
# 1  yes    451

# %%
plt.figure(figsize=(50,50))
sns.set(style="whitegrid")

categorical_columns = ['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact', 'month', 'day_of_week', 'poutcome', 'y']

fig, axes = plt.subplots(nrows=4, ncols=3, figsize=(20, 20))
fig.subplots_adjust(hspace=0.5)

for ax, column in zip(axes.flatten(), categorical_columns):
    sns.countplot(data=Bank, x=column, ax=ax)
    ax.set_title(f'Distribution of {column}')
    ax.set_xticklabels(ax.get_xticklabels(), rotation=45)

plt.tight_layout()
plt.show()

# %%
numarical_columns=Bank.select_dtypes(exclude=object).columns
numarical_columns
# Out:
# Index(['age', 'duration', 'campaign', 'pdays', 'previous', 'emp.var.rate',
#        'cons.price.idx', 'cons.conf.idx', 'euribor3m', 'nr.employed'],
#       dtype='object')

# %%
descriptive_stats = round(Bank.describe(exclude=object),2)
descriptive_stats
# Out:
#            age  duration  campaign    pdays  previous  emp.var.rate  \
# count  4119.00   4119.00   4119.00  4119.00   4119.00       4119.00
# mean     40.11    256.79      2.54   960.42      0.19          0.08
# std      10.31    254.70      2.57   191.92      0.54          1.56
# min      18.00      0.00      1.00     0.00      0.00         -3.40
# 25%      32.00    103.00      1.00   999.00      0.00         -1.80
# 50%      38.00    181.00      2.00   999.00      0.00          1.10
# 75%      47.00    317.00      3.00   999.00      0.00          1.40
# max      88.00   3643.00     35.00   999.00      6.00          1.40
#
#        cons.price.idx  cons.conf.idx  euribor3m  nr.employed
# count         4119.00        4119.00    4119.00      4119.00
# mean            93.58         -40.50       3.62      5166.48
# std              0.58           4.59       1.73        73.67
# min             92.20         -50.80       0.64      4963.60
# ...

# %%
plt.figure(figsize=(20,30))
plt.subplot(5,2,1)
plt.hist(bank['age'])
plt.title("Histogram")
plt.xlabel("class Interval")
plt.ylabel("count")

plt.subplot(5,2,2)
plt.hist(bank['duration'])
plt.title("Histogram")
plt.xlabel("class Interval")
plt.ylabel("count")

plt.subplot(5,2,3)
plt.hist(bank['campaign'])
plt.title("Histogram")
plt.xlabel("class Interval")
plt.ylabel("count")

plt.subplot(5,2,4)
plt.hist(bank['pdays'])
plt.title("Histogram")
plt.xlabel("class Interval")
plt.ylabel("count")

plt.subplot(5,2,5)
plt.hist(bank['previous'])
plt.title("Histogram")
plt.xlabel("class Interval")
plt.ylabel("count")

plt.subplot(5,2,6)
plt.hist(bank['emp.var.rate'])
plt.title("Histogram")
plt.xlabel("class Interval")
plt.ylabel("count")

plt.subplot(5,2,7)
plt.hist(bank['cons.price.idx'])
plt.title("Histogram")
plt.xlabel("class Interval")
plt.ylabel("count")

plt.subplot(5,2,8)
plt.hist(bank['cons.conf.idx'])
plt.title("Histogram")
plt.xlabel("class Interval")
plt.ylabel("count")

plt.subplot(5,2,9)
plt.hist(bank['euribor3m'])
plt.title("Histogram")
plt.xlabel("class Interval")
plt.ylabel("count")

plt.subplot(5,2,10)
plt.hist(bank['nr.employed'])
plt.title("Histogram")
plt.xlabel("class Interval")
plt.ylabel("count")
plt.show()

# %%
Q1=round(np.percentile(bank['age'], 25), 2)
Q3=round(np.percentile(bank['age'], 75), 2)
IQR=Q3-Q1
LB= Q1-1.5*IQR
UB= Q3+1.5*IQR
con1=bank['age']<LB
con2=bank['age']>UB
outliers_data=bank[con1 | con2]
outliers_data
# Out:
#       age          job   marital            education  default housing loan  \
# 42     76      retired   married    university.degree       no      no   no
# 128    75      retired   married             basic.4y       no      no   no
# 150    82    housemaid   married             basic.4y       no      no   no
# 167    71  blue-collar  divorced             basic.4y  unknown      no   no
# 228    76      retired    single             basic.4y       no      no   no
# 338    81      retired   married             basic.4y       no      no   no
# 450    73      retired   married    university.degree       no     yes   no
# 537    74      retired   married    university.degree       no      no   no
# 589    77   management   married              unknown       no     yes   no
# 696    86      retired   married              unknown  unknown     yes  yes
# 750    75      retired   married    university.degree       no     yes   no
# ...

# %%
Q3=round(np.percentile(bank['duration'], 25), 2)
Q4=round(np.percentile(bank['duration'], 75), 2)
IQR=Q4-Q3
LB= Q3-1.5*IQR
UB= Q4+1.5*IQR
con3=bank['duration']<LB
con4=bank['duration']>UB
outliers_data=bank[con3 | con4]
outliers_data
# Out:
#       age          job  marital            education  default housing loan  \
# 15     27     services   single    university.degree       no      no   no
# 19     50  blue-collar  married             basic.4y       no      no  yes
# 68     32  blue-collar  married             basic.9y       no      no   no
# 74     31   technician   single          high.school       no     yes  yes
# 80     54   technician  married  professional.course  unknown     yes   no
# ...   ...          ...      ...                  ...      ...     ...  ...
# 4059   36     services  married          high.school       no      no  yes
# 4069   60       admin.  married    university.degree       no     yes   no
# 4072   32  blue-collar  married  professional.course       no     yes   no
# 4091   38   management  married          high.school  unknown      no   no
# 4109   63      retired  married          high.school       no      no   no
#
#         contact month day_of_week  ...  campaign  pdays  previous  \
# ...
